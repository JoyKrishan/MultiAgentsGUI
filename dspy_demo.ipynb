# %%
import os
from dotenv import load_dotenv
_ = load_dotenv()
import dspy

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model="gpt-4o",
    api_key = os.getenv("GITHUB_TOKEN"),
    base_url= "https://models.inference.ai.azure.com/v1"
)
model.chat

# %%
from litellm import completion
import os

os.environ['GITHUB_API_KEY'] = os.environ['GITHUB_TOKEN']
response = completion(
    model="github/llama3-8b-8192", 
    messages=[
       {"role": "user", "content": "hello from litellm"}
   ],
)
print(response)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:854, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     853             else:
# --> 854                 raise e
#     855 except OpenAIError as e:
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:790, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     778 logging_obj.pre_call(
#     779     input=messages,
#     780     api_key=openai_client.api_key,
#    (...)
#     786     },
#     787 )
#     789 headers, response = (
# --> 790     self.make_sync_openai_chat_completion_request(
#     791         openai_client=openai_client,
#     792         data=data,
#     793         timeout=timeout,
#     794     )
#     795 )
#     797 logging_obj.model_call_details["response_headers"] = headers
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:649, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout)
#     648 else:
# --> 649     raise e
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:631, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout)
#     630 try:
# --> 631     raw_response = openai_client.chat.completions.with_raw_response.create(
#     632         **data, timeout=timeout
#     633     )
#     635     if hasattr(raw_response, "headers"):
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_legacy_response.py:356, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     354 kwargs["extra_headers"] = extra_headers
# --> 356 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/resources/chat/completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     828 validate_response_format(response_format)
# --> 829 return self._post(
#     830     "/chat/completions",
#     831     body=maybe_transform(
#     832         {
#     833             "messages": messages,
#     834             "model": model,
#     835             "audio": audio,
#     836             "frequency_penalty": frequency_penalty,
#     837             "function_call": function_call,
#     838             "functions": functions,
#     839             "logit_bias": logit_bias,
#     840             "logprobs": logprobs,
#     841             "max_completion_tokens": max_completion_tokens,
#     842             "max_tokens": max_tokens,
#     843             "metadata": metadata,
#     844             "modalities": modalities,
#     845             "n": n,
#     846             "parallel_tool_calls": parallel_tool_calls,
#     847             "prediction": prediction,
#     848             "presence_penalty": presence_penalty,
#     849             "response_format": response_format,
#     850             "seed": seed,
#     851             "service_tier": service_tier,
#     852             "stop": stop,
#     853             "store": store,
#     854             "stream": stream,
#     855             "stream_options": stream_options,
#     856             "temperature": temperature,
#     857             "tool_choice": tool_choice,
#     858             "tools": tools,
#     859             "top_logprobs": top_logprobs,
#     860             "top_p": top_p,
#     861             "user": user,
#     862         },
#     863         completion_create_params.CompletionCreateParams,
#     864     ),
#     865     options=make_request_options(
#     866         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867     ),
#     868     cast_to=ChatCompletion,
#     869     stream=stream or False,
#     870     stream_cls=Stream[ChatCompletionChunk],
#     871 )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_base_client.py:1278, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1275 opts = FinalRequestOptions.construct(
#    1276     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1277 )
# -> 1278 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_base_client.py:1059, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1058     log.debug("Re-raising status error")
# -> 1059     raise self._make_status_error_from_response(err.response) from None
#    1061 return self._process_response(
#    1062     cast_to=cast_to,
#    1063     options=options,
#    (...)
#    1067     retries_taken=retries_taken,
#    1068 )
#
# AuthenticationError: Error code: 401 - {'error': {'code': 'unauthorized', 'message': 'Bad credentials', 'details': 'Bad credentials'}}
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/main.py:1597, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1591     logging.post_call(
#    1592         input=messages,
#    1593         api_key=api_key,
#    1594         original_response=str(e),
#    1595         additional_args={"headers": headers},
#    1596     )
# -> 1597     raise e
#    1599 if optional_params.get("stream", False):
#    1600     ## LOGGING
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/main.py:1570, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1569     else:
# -> 1570         response = openai_chat_completions.completion(
#    1571             model=model,
#    1572             messages=messages,
#    1573             headers=headers,
#    1574             model_response=model_response,
#    1575             print_verbose=print_verbose,
#    1576             api_key=api_key,
#    1577             api_base=api_base,
#    1578             acompletion=acompletion,
#    1579             logging_obj=logging,
#    1580             optional_params=optional_params,
#    1581             litellm_params=litellm_params,
#    1582             logger_fn=logger_fn,
#    1583             timeout=timeout,  # type: ignore
#    1584             custom_prompt_dict=custom_prompt_dict,
#    1585             client=client,  # pass AsyncOpenAI, OpenAI client
#    1586             organization=organization,
#    1587             custom_llm_provider=custom_llm_provider,
#    1588         )
#    1589 except Exception as e:
#    1590     ## LOGGING - log the original exception returned
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:864, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     863     error_headers = getattr(error_response, "headers", None)
# --> 864 raise OpenAIError(
#     865     status_code=status_code, message=error_text, headers=error_headers
#     866 )
#
# OpenAIError: Error code: 401 - {'error': {'code': 'unauthorized', 'message': 'Bad credentials', 'details': 'Bad credentials'}}
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[33], line 5
#       2 import os
#       4 os.environ['GITHUB_API_KEY'] = os.environ['GITHUB_TOKEN']
# ----> 5 response = completion(
#       6     model="github/llama3-8b-8192",
#       7     messages=[
#       8        {"role": "user", "content": "hello from litellm"}
#       9    ],
#      10 )
#      11 print(response)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/utils.py:1013, in client.<locals>.wrapper(*args, **kwargs)
#    1009 if logging_obj:
#    1010     logging_obj.failure_handler(
#    1011         e, traceback_exception, start_time, end_time
#    1012     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1013 raise e
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/utils.py:903, in client.<locals>.wrapper(*args, **kwargs)
#     901         print_verbose(f"Error while checking max token limit: {str(e)}")
#     902 # MODEL CALL
# --> 903 result = original_function(*args, **kwargs)
#     904 end_time = datetime.datetime.now()
#     905 if "stream" in kwargs and kwargs["stream"] is True:
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/main.py:3009, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    3006     return response
#    3007 except Exception as e:
#    3008     ## Map to OpenAI Exception
# -> 3009     raise exception_type(
#    3010         model=model,
#    3011         custom_llm_provider=custom_llm_provider,
#    3012         original_exception=e,
#    3013         completion_kwargs=args,
#    3014         extra_kwargs=kwargs,
#    3015     )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2116, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2114 if exception_mapping_worked:
#    2115     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2116     raise e
#    2117 else:
#    2118     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:343, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     341 elif original_exception.status_code == 401:
#     342     exception_mapping_worked = True
# --> 343     raise AuthenticationError(
#     344         message=f"AuthenticationError: {exception_provider} - {message}",
#     345         llm_provider=custom_llm_provider,
#     346         model=model,
#     347         response=original_exception.response,
#     348         litellm_debug_info=extra_information,
#     349     )
#     350 elif original_exception.status_code == 404:
#     351     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: GithubException - Error code: 401 - {'error': {'code': 'unauthorized', 'message': 'Bad credentials', 'details': 'Bad credentials'}}

# %%
import os 
import litellm
from litellm import completion

client = litellm.LiteLLM(
    base_url="https://models.inference.ai.azure.com/v1",
    api_key=os.environ["GITHUB_TOKEN"],
)


response = client.chat.completions.create(
    messages=[{"content": "Who is the most renowned French painter?", "role": "user"}],
    model="gpt-4o",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 11
#       3 from litellm import completion
#       5 client = litellm.LiteLLM(
#       6     base_url="https://models.inference.ai.azure.com/v1",
#       7     api_key=os.environ["GITHUB_TOKEN"],
#       8 )
# ---> 11 response = client.chat.completions.create(
#      12     messages=[{"content": "Who is the most renowned French painter?", "role": "user"}],
#      13     model="gpt-4o",
#      14 )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/main.py:269, in Completions.create(self, messages, model, **kwargs)
#     265     response = self.router_obj.completion(
#     266         model=model, messages=messages, **self.params
#     267     )
#     268 else:
# --> 269     response = completion(model=model, messages=messages, **self.params)
#     270 return response
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/utils.py:1013, in client.<locals>.wrapper(*args, **kwargs)
#    1009 if logging_obj:
#    1010     logging_obj.failure_handler(
#    1011         e, traceback_exception, start_time, end_time
#    1012     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1013 raise e
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/utils.py:857, in client.<locals>.wrapper(*args, **kwargs)
#     835 if (
#     836     (
#     837         (
#    (...)
#     853 ):  # allow users to control returning cached responses from the completion function
#     854     # checking cache
#     855     print_verbose("INSIDE CHECKING CACHE")
#     856     caching_handler_response: CachingHandlerResponse = (
# --> 857         _llm_caching_handler._sync_get_cache(
#     858             model=model or "",
#     859             original_function=original_function,
#     860             logging_obj=logging_obj,
#     861             start_time=start_time,
#     862             call_type=call_type,
#     863             kwargs=kwargs,
#     864             args=args,
#     865         )
#     866     )
#     867     if caching_handler_response.cached_result is not None:
#     868         return caching_handler_response.cached_result
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/caching/caching_handler.py:241, in LLMCachingHandler._sync_get_cache(self, model, original_function, logging_obj, start_time, call_type, kwargs, args)
#     237 if litellm.cache is not None and self._is_call_type_supported_by_cache(
#     238     original_function=original_function
#     239 ):
#     240     print_verbose("Checking Cache")
# --> 241     cached_result = litellm.cache.get_cache(*args, **kwargs)
#     242     if cached_result is not None:
#     243         if "detail" in cached_result:
#     244             # implies an error occurred
#
# TypeError: Cache.get_cache() got multiple values for argument 'self'

# %%
lm = dspy.LM("openai/gpt-4o", 
             api_key=os.environ["GITHUB_TOKEN"], 
             api_base="https://models.inference.ai.azure.com")

# %%
lm("Hello")
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:854, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     853             else:
# --> 854                 raise e
#     855 except OpenAIError as e:
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:790, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     778 logging_obj.pre_call(
#     779     input=messages,
#     780     api_key=openai_client.api_key,
#    (...)
#     786     },
#     787 )
#     789 headers, response = (
# --> 790     self.make_sync_openai_chat_completion_request(
#     791         openai_client=openai_client,
#     792         data=data,
#     793         timeout=timeout,
#     794     )
#     795 )
#     797 logging_obj.model_call_details["response_headers"] = headers
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:649, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout)
#     648 else:
# --> 649     raise e
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:631, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout)
#     630 try:
# --> 631     raw_response = openai_client.chat.completions.with_raw_response.create(
#     632         **data, timeout=timeout
#     633     )
#     635     if hasattr(raw_response, "headers"):
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_legacy_response.py:356, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     354 kwargs["extra_headers"] = extra_headers
# --> 356 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/resources/chat/completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     828 validate_response_format(response_format)
# --> 829 return self._post(
#     830     "/chat/completions",
#     831     body=maybe_transform(
#     832         {
#     833             "messages": messages,
#     834             "model": model,
#     835             "audio": audio,
#     836             "frequency_penalty": frequency_penalty,
#     837             "function_call": function_call,
#     838             "functions": functions,
#     839             "logit_bias": logit_bias,
#     840             "logprobs": logprobs,
#     841             "max_completion_tokens": max_completion_tokens,
#     842             "max_tokens": max_tokens,
#     843             "metadata": metadata,
#     844             "modalities": modalities,
#     845             "n": n,
#     846             "parallel_tool_calls": parallel_tool_calls,
#     847             "prediction": prediction,
#     848             "presence_penalty": presence_penalty,
#     849             "response_format": response_format,
#     850             "seed": seed,
#     851             "service_tier": service_tier,
#     852             "stop": stop,
#     853             "store": store,
#     854             "stream": stream,
#     855             "stream_options": stream_options,
#     856             "temperature": temperature,
#     857             "tool_choice": tool_choice,
#     858             "tools": tools,
#     859             "top_logprobs": top_logprobs,
#     860             "top_p": top_p,
#     861             "user": user,
#     862         },
#     863         completion_create_params.CompletionCreateParams,
#     864     ),
#     865     options=make_request_options(
#     866         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867     ),
#     868     cast_to=ChatCompletion,
#     869     stream=stream or False,
#     870     stream_cls=Stream[ChatCompletionChunk],
#     871 )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_base_client.py:1278, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1275 opts = FinalRequestOptions.construct(
#    1276     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1277 )
# -> 1278 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_base_client.py:1059, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1058     log.debug("Re-raising status error")
# -> 1059     raise self._make_status_error_from_response(err.response) from None
#    1061 return self._process_response(
#    1062     cast_to=cast_to,
#    1063     options=options,
#    (...)
#    1067     retries_taken=retries_taken,
#    1068 )
#
# AuthenticationError: Error code: 401 - {'error': {'code': 'unauthorized', 'message': 'Bad credentials', 'details': 'Bad credentials'}}
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/main.py:1597, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1591     logging.post_call(
#    1592         input=messages,
#    1593         api_key=api_key,
#    1594         original_response=str(e),
#    1595         additional_args={"headers": headers},
#    1596     )
# -> 1597     raise e
#    1599 if optional_params.get("stream", False):
#    1600     ## LOGGING
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/main.py:1570, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    1569     else:
# -> 1570         response = openai_chat_completions.completion(
#    1571             model=model,
#    1572             messages=messages,
#    1573             headers=headers,
#    1574             model_response=model_response,
#    1575             print_verbose=print_verbose,
#    1576             api_key=api_key,
#    1577             api_base=api_base,
#    1578             acompletion=acompletion,
#    1579             logging_obj=logging,
#    1580             optional_params=optional_params,
#    1581             litellm_params=litellm_params,
#    1582             logger_fn=logger_fn,
#    1583             timeout=timeout,  # type: ignore
#    1584             custom_prompt_dict=custom_prompt_dict,
#    1585             client=client,  # pass AsyncOpenAI, OpenAI client
#    1586             organization=organization,
#    1587             custom_llm_provider=custom_llm_provider,
#    1588         )
#    1589 except Exception as e:
#    1590     ## LOGGING - log the original exception returned
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/llms/OpenAI/openai.py:864, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, logging_obj, model, messages, print_verbose, api_key, api_base, acompletion, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     863     error_headers = getattr(error_response, "headers", None)
# --> 864 raise OpenAIError(
#     865     status_code=status_code, message=error_text, headers=error_headers
#     866 )
#
# OpenAIError: Error code: 401 - {'error': {'code': 'unauthorized', 'message': 'Bad credentials', 'details': 'Bad credentials'}}
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/utils.py:903, in client.<locals>.wrapper(*args, **kwargs)
#     902 # MODEL CALL
# --> 903 result = original_function(*args, **kwargs)
#     904 end_time = datetime.datetime.now()
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/main.py:3009, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    3007 except Exception as e:
#    3008     ## Map to OpenAI Exception
# -> 3009     raise exception_type(
#    3010         model=model,
#    3011         custom_llm_provider=custom_llm_provider,
#    3012         original_exception=e,
#    3013         completion_kwargs=args,
#    3014         extra_kwargs=kwargs,
#    3015     )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2116, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2115     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2116     raise e
#    2117 else:
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:343, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     342     exception_mapping_worked = True
# --> 343     raise AuthenticationError(
#     344         message=f"AuthenticationError: {exception_provider} - {message}",
#     345         llm_provider=custom_llm_provider,
#     346         model=model,
#     347         response=original_exception.response,
#     348         litellm_debug_info=extra_information,
#     349     )
#     350 elif original_exception.status_code == 404:
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - Error code: 401 - {'error': {'code': 'unauthorized', 'message': 'Bad credentials', 'details': 'Bad credentials'}}
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 lm("Hello")
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/utils/callback.py:202, in with_callbacks.<locals>.wrapper(instance, *args, **kwargs)
#     200 # If no callbacks are provided, just call the function
#     201 if not callbacks:
# --> 202     return fn(instance, *args, **kwargs)
#     204 # Generate call ID as the unique identifier for the call, this is useful for instrumentation.
#     205 call_id = uuid.uuid4().hex
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/clients/lm.py:94, in LM.__call__(self, prompt, messages, **kwargs)
#      91 else:
#      92     completion = cached_litellm_text_completion if cache else litellm_text_completion
# ---> 94 response = completion(
#      95     request=ujson.dumps(dict(model=self.model, messages=messages, **kwargs)),
#      96     num_retries=self.num_retries,
#      97 )
#      98 outputs = [c.message.content if hasattr(c, "message") else c["text"] for c in response["choices"]]
#     100 # Logging, with removed api key & where `cost` is None on cache hit.
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/clients/lm.py:217, in cached_litellm_completion(request, num_retries)
#     215 @functools.lru_cache(maxsize=None)
#     216 def cached_litellm_completion(request, num_retries: int):
# --> 217     return litellm_completion(
#     218         request,
#     219         cache={"no-cache": False, "no-store": False},
#     220         num_retries=num_retries,
#     221     )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/clients/lm.py:226, in litellm_completion(request, num_retries, cache)
#     224 def litellm_completion(request, num_retries: int, cache={"no-cache": True, "no-store": True}):
#     225     kwargs = ujson.loads(request)
# --> 226     return litellm.completion(
#     227         num_retries=num_retries,
#     228         cache=cache,
#     229         **kwargs,
#     230     )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/utils.py:993, in client.<locals>.wrapper(*args, **kwargs)
#     987     if (
#     988         isinstance(e, openai.APIError)
#     989         or isinstance(e, openai.Timeout)
#     990         or isinstance(e, openai.APIConnectionError)
#     991     ):
#     992         kwargs["num_retries"] = num_retries
# --> 993         return litellm.completion_with_retries(*args, **kwargs)
#     994 elif (
#     995     isinstance(e, litellm.exceptions.ContextWindowExceededError)
#     996     and context_window_fallback_dict
#     997     and model in context_window_fallback_dict
#     998     and not _is_litellm_router_call
#     999 ):
#    1000     if len(args) > 0:
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/main.py:3042, in completion_with_retries(*args, **kwargs)
#    3038 else:
#    3039     retryer = tenacity.Retrying(
#    3040         stop=tenacity.stop_after_attempt(num_retries), reraise=True
#    3041     )
# -> 3042 return retryer(original_function, *args, **kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/utils.py:1013, in client.<locals>.wrapper(*args, **kwargs)
#    1009 if logging_obj:
#    1010     logging_obj.failure_handler(
#    1011         e, traceback_exception, start_time, end_time
#    1012     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1013 raise e
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/utils.py:903, in client.<locals>.wrapper(*args, **kwargs)
#     901         print_verbose(f"Error while checking max token limit: {str(e)}")
#     902 # MODEL CALL
# --> 903 result = original_function(*args, **kwargs)
#     904 end_time = datetime.datetime.now()
#     905 if "stream" in kwargs and kwargs["stream"] is True:
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/main.py:3009, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, **kwargs)
#    3006     return response
#    3007 except Exception as e:
#    3008     ## Map to OpenAI Exception
# -> 3009     raise exception_type(
#    3010         model=model,
#    3011         custom_llm_provider=custom_llm_provider,
#    3012         original_exception=e,
#    3013         completion_kwargs=args,
#    3014         extra_kwargs=kwargs,
#    3015     )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2116, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2114 if exception_mapping_worked:
#    2115     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2116     raise e
#    2117 else:
#    2118     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:343, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     341 elif original_exception.status_code == 401:
#     342     exception_mapping_worked = True
# --> 343     raise AuthenticationError(
#     344         message=f"AuthenticationError: {exception_provider} - {message}",
#     345         llm_provider=custom_llm_provider,
#     346         model=model,
#     347         response=original_exception.response,
#     348         litellm_debug_info=extra_information,
#     349     )
#     350 elif original_exception.status_code == 404:
#     351     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - Error code: 401 - {'error': {'code': 'unauthorized', 'message': 'Bad credentials', 'details': 'Bad credentials'}}

# %%
math = dspy.ChainOfThought("question -> answer: float")
math(question="Two dice are tossed. What is the probability that the sum equals two?")
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 math = dspy.ChainOfThought("question -> answer: float")
# ----> 2 math(question="Two dice are tossed. What is the probability that the sum equals two?")
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/utils/callback.py:202, in with_callbacks.<locals>.wrapper(instance, *args, **kwargs)
#     200 # If no callbacks are provided, just call the function
#     201 if not callbacks:
# --> 202     return fn(instance, *args, **kwargs)
#     204 # Generate call ID as the unique identifier for the call, this is useful for instrumentation.
#     205 call_id = uuid.uuid4().hex
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/primitives/program.py:24, in Module.__call__(self, *args, **kwargs)
#      22 @with_callbacks
#      23 def __call__(self, *args, **kwargs):
# ---> 24     return self.forward(*args, **kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/predict/chain_of_thought.py:44, in ChainOfThought.forward(self, **kwargs)
#      41 assert self.activated in [True, False]
#      43 signature = kwargs.pop("new_signature", self._predict.extended_signature if self.activated else self.signature)
# ---> 44 return self._predict(signature=signature, **kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/utils/callback.py:202, in with_callbacks.<locals>.wrapper(instance, *args, **kwargs)
#     200 # If no callbacks are provided, just call the function
#     201 if not callbacks:
# --> 202     return fn(instance, *args, **kwargs)
#     204 # Generate call ID as the unique identifier for the call, this is useful for instrumentation.
#     205 call_id = uuid.uuid4().hex
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/predict/predict.py:154, in Predict.__call__(self, **kwargs)
#     152 @with_callbacks
#     153 def __call__(self, **kwargs):
# --> 154     return self.forward(**kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/predict/predict.py:203, in Predict.forward(self, **kwargs)
#     201         completions = new_generate(lm, signature, dsp.Example(demos=demos, **kwargs), **config)
#     202     else:
# --> 203         completions = old_generate(demos, signature, kwargs, config, self.lm, self.stage)
#     205 pred = Prediction.from_completions(completions, signature=signature)
#     207 if kwargs.pop("_trace", True) and dsp.settings.trace is not None:
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dspy/predict/predict.py:229, in old_generate(demos, signature, kwargs, config, lm, stage)
#     226 template = signature_to_template(signature)
#     228 if lm is None:
# --> 229     x, C = dsp.generate(template, **config)(x, stage=stage)
#     230 else:
#     231     # Note: query_only=True means the instructions and examples are not included.
#     232     with dsp.settings.context(lm=lm, query_only=True):
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dsp/primitives/predict.py:73, in _generate.<locals>.do_generate(example, stage, max_depth, original_example)
#      71 # Generate and extract the fields.
#      72 prompt = template(example)
# ---> 73 completions: list[dict[str, Any]] = generator(prompt, **kwargs)
#      74 completions: list[Example] = [template.extract(example, p) for p in completions]
#      76 # Find the completions that are most complete.
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dsp/modules/gpt3.py:199, in GPT3.__call__(self, prompt, only_completed, return_sorted, **kwargs)
#     191 assert return_sorted is False, "for now"
#     193 # if kwargs.get("n", 1) > 1:
#     194 #     if self.model_type == "chat":
#     195 #         kwargs = {**kwargs}
#     196 #     else:
#     197 #         kwargs = {**kwargs, "logprobs": 5}
# --> 199 response = self.request(prompt, **kwargs)
#     201 self.log_usage(response)
#     202 choices = response["choices"]
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/backoff/_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#      96 details = {
#      97     "target": target,
#      98     "args": args,
#    (...)
#     101     "elapsed": elapsed,
#     102 }
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#     107     max_tries_exceeded = (tries == max_tries_value)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dsp/modules/gpt3.py:165, in GPT3.request(self, prompt, **kwargs)
#     162 if "model_type" in kwargs:
#     163     del kwargs["model_type"]
# --> 165 return self.basic_request(prompt, **kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dsp/modules/gpt3.py:138, in GPT3.basic_request(self, prompt, **kwargs)
#     136     kwargs["messages"] = messages
#     137     kwargs = {"stringify_request": json.dumps(kwargs)}
# --> 138     response = chat_request(**kwargs)
#     140 else:
#     141     kwargs["prompt"] = prompt
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dsp/modules/gpt3.py:290, in chat_request(**kwargs)
#     287 if OPENAI_LEGACY:
#     288     return _cached_gpt3_turbo_request_v2_wrapped(**kwargs)
# --> 290 return v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs).model_dump()
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dsp/modules/cache_utils.py:16, in noop_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      14 @wraps(func)
#      15 def wrapper(*args, **kwargs):
# ---> 16     return func(*args, **kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dsp/modules/gpt3.py:283, in v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs)
#     280 @functools.lru_cache(maxsize=None if cache_turn_on else 0)
#     281 @NotebookCacheMemory.cache
#     282 def v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs):
# --> 283     return v1_cached_gpt3_turbo_request_v2(**kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/joblib/memory.py:577, in MemorizedFunc.__call__(self, *args, **kwargs)
#     575 def __call__(self, *args, **kwargs):
#     576     # Return the output, without the metadata
# --> 577     return self._cached_call(args, kwargs, shelving=False)[0]
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/joblib/memory.py:532, in MemorizedFunc._cached_call(self, args, kwargs, shelving)
#     526     self.warn(
#     527         f"Computing func {func_name}, argument hash {args_id} "
#     528         f"in location {location}"
#     529     )
#     531 # Returns the output but not the metadata
# --> 532 return self._call(call_id, args, kwargs, shelving)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/joblib/memory.py:771, in MemorizedFunc._call(self, call_id, args, kwargs, shelving)
#     769 self._before_call(args, kwargs)
#     770 start_time = time.time()
# --> 771 output = self.func(*args, **kwargs)
#     772 return self._after_call(call_id, args, kwargs, shelving,
#     773                         output, start_time)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/dsp/modules/gpt3.py:277, in v1_cached_gpt3_turbo_request_v2(**kwargs)
#     275 if "stringify_request" in kwargs:
#     276     kwargs = json.loads(kwargs["stringify_request"])
# --> 277 return openai.chat.completions.create(**kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/resources/chat/completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_base_client.py:1278, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1264 def post(
#    1265     self,
#    1266     path: str,
#    (...)
#    1273     stream_cls: type[_StreamT] | None = None,
#    1274 ) -> ResponseT | _StreamT:
#    1275     opts = FinalRequestOptions.construct(
#    1276         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1277     )
# -> 1278     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952 else:
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File ~/Projects/APRGui/.venv/lib/python3.12/site-packages/openai/_base_client.py:1059, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1056         err.response.read()
#    1058     log.debug("Re-raising status error")
# -> 1059     raise self._make_status_error_from_response(err.response) from None
#    1061 return self._process_response(
#    1062     cast_to=cast_to,
#    1063     options=options,
#    (...)
#    1067     retries_taken=retries_taken,
#    1068 )
#
# AuthenticationError: Error code: 401 - {'error': {'code': 'unauthorized', 'message': 'Bad credentials', 'details': 'Bad credentials'}}
